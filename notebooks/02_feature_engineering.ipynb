# %% [markdown]
# # DataMind AI — 02 Feature Engineering & RFM Extraction
# Extracts Recency, Frequency, Monetary value, customer behavioral complaint features, and rolling time series lags.

# %%
from app.data.preprocessing import FeatureEngineeringPipeline

df_churn_feats = FeatureEngineeringPipeline.build_customer_churn_features()
print('Customer Churn Feature Matrix Shape:', df_churn_feats.shape)
df_churn_feats.head()

# %%
df_ts_feats = FeatureEngineeringPipeline.build_sales_time_series_features()
print('Time-series Feature Matrix Shape:', df_ts_feats.shape)
df_ts_feats.tail()
