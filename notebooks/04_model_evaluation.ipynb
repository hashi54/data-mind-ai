# %% [markdown]
# # DataMind AI — 04 Model Evaluation & SHAP Explainability
# Inspects ROC curves, precision-recall trade-offs, SHAP local waterfall attributions, and residual diagnostics.

# %%
from app.ml.inference.churn_predictor import ChurnInferenceEngine
from app.ml.inference.forecaster import SalesForecasterEngine

# 1. Churn Prediction & SHAP Breakdown
churn_res = ChurnInferenceEngine.predict(customer_id=1)
print('Customer Churn Prediction:', churn_res)

# 2. Forward Sales Forecast
fc_res = SalesForecasterEngine.forecast(horizon='30d')
print('30-Day Forecast:', fc_res['total_predicted_revenue'])
