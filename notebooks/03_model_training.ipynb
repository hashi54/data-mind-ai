# %% [markdown]
# # DataMind AI — 03 Model Training Pipelines
# Trains candidate models across Churn, Sales Forecasting, Customer Segmentation, and CLV.

# %%
from app.ml.training.train_churn import train_customer_churn_models
from app.ml.training.train_forecasting import train_sales_forecasting_models
from app.ml.training.train_segmentation import train_customer_segmentation
from app.ml.training.train_clv import train_clv_model

churn_summary = train_customer_churn_models()
fc_summary = train_sales_forecasting_models()
seg_summary = train_customer_segmentation()
clv_summary = train_clv_model()
